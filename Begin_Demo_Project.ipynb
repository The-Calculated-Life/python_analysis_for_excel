# %% [markdown]
# <a href="https://colab.research.google.com/github/The-Calculated-Life/python_analysis_for_excel/blob/main/Begin_Demo_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **An Analysis of Kiva Crowdfunded Loans**
#
# ###### *Cory Stahle: Udemy Course Project Demo*
# ---

# %% [markdown]
# ![micheile-henderson-lZ_4nPFKcV8-unsplash (1).jpg](data:image/jpeg;base64,...)
#
# <span>Photo by <a href="https://unsplash.com/@micheile?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Micheile Henderson</a> on <a href="https://unsplash.com/s/photos/money?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Unsplash</a></span>

# %% [markdown]
# <br><br>
#
# ***Project structure:***
#
#
# 1.   Define the objective
# 2.   Import packages and data
# 3.   Explore and clean
# 4.   Analyze

# %% [markdown]
# <br>
#
# ## **Objective**
# ---
#
# *Analyze the [Kiva.org](https://www.kiva.org/) lending platform. Understand how much money has been borrowed, for what purpose, and where the borrowers live.*
#
# <br>
#
# In particular, we want to answer the following groups of questions:
#
#
#
# 1.   How much money has been borrowed through Kiva's lending platform? How has the amount of funding changed over time?
# 2.   How much funding has been provided by category (theme)?
# 3.   How does funding vary by world region? What are the most popular themes in each region?

# %% [markdown]
# <br><br>
#
# ## **Import Packages and Data**
# ---
#
#
# The data for this project comes from [Kaggle.com](https://www.kaggle.com/kiva/data-science-for-good-kiva-crowdfunding). It includes information about loans funded between January 1, 2016 and July 26th, 2017.
#
# The data is also stored on the GitHub page for the course [here](https://github.com/The-Calculated-Life/python_analysis_for_excel/tree/main/data)

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading https://files.pythonhosted.org/packages/0b/2b/2e77c35326efec19819cd1d729540d4d235e6c2a3f37658288a363a67da5/squarify-0.4.3-py3-none-any.whl
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import squarify

plt.rcParams['figure.figsize'] = [12, 6]

# %%
kiva_loans_path = 'https://raw.githubusercontent.com/The-Calculated-Life/python_analysis_for_excel/main/data/kiva_loans.csv'
locations_path = 'https://raw.githubusercontent.com/The-Calculated-Life/python_analysis_for_excel/main/data/kiva_mpi_region_locations.csv'

kiva_loans = pd.read_csv(kiva_loans_path)
locations = pd.read_csv(locations_path)

# %% [markdown]
# <br><br>
#
# ## **Explore and Clean Data**
# ---

# %% [markdown]
# ### kiva_loans dataframe

# %%
kiva_loans.head()
# Out:
#         id  funded_amount  ...  repayment_interval      date
# 0  1002924            500  ...             monthly  1/1/2016
# 1  1002908            500  ...           irregular  1/1/2016
# 2  1002897            500  ...             monthly  1/1/2016
# 3  1002916            500  ...           irregular  1/1/2016
# 4  1002891            575  ...           irregular  1/1/2016
#
# [5 rows x 14 columns]

# %%
kiva_loans.shape
# Out:
# (315138, 14)

# %%
kiva_loans.isnull().sum()
# Out:
# id                        0
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# country_code              4
# country                   0
# region                16367
# currency                  0
# partner_id             3070
# term_in_months            0
# lender_count              0
# repayment_interval        0
# date                      0
# dtype: int64

# %%
kiva_loans['date'] = pd.to_datetime(kiva_loans['date'])
kiva_loans = kiva_loans.set_index('date')

# %%
kiva_loans.head()
# Out:
#                  id  funded_amount  ...  lender_count repayment_interval
# date                                ...
# 2016-01-01  1002924            500  ...             1            monthly
# 2016-01-01  1002908            500  ...             1          irregular
# 2016-01-01  1002897            500  ...            17            monthly
# 2016-01-01  1002916            500  ...            16          irregular
# 2016-01-01  1002891            575  ...            21          irregular
#
# [5 rows x 13 columns]

# %% [markdown]
# <br><br>
#
# ### locations dataframe

# %%
locations.head()
# Out:
#               LocationName  ISO  ...        lat        lon
# 0  Badakhshan, Afghanistan  AFG  ...  36.734772  70.811995
# 1     Badghis, Afghanistan  AFG  ...  35.167134  63.769538
# 2     Baghlan, Afghanistan  AFG  ...  35.804295  69.287754
# 3       Balkh, Afghanistan  AFG  ...  36.755060  66.897537
# 4      Bamyan, Afghanistan  AFG  ...  34.810007  67.821210
#
# [5 rows x 9 columns]

# %%
locations.shape
# Out:
# (2772, 9)

# %%
locations.isnull().sum()
# Out:
# LocationName    1788
# ISO             1764
# country         1764
# region          1788
# world_region    1764
# MPI             1788
# geo                0
# lat             1880
# lon             1880
# dtype: int64

# %%
locations[(locations['world_region'].isnull()) & (locations['country'].notnull())]
# Out:
# Empty DataFrame
# Columns: [LocationName, ISO, country, region, world_region, MPI, geo, lat, lon]
# Index: []

# %%
locations = locations.dropna()

# %%
locations.shape
# Out:
# (892, 9)

# %% [markdown]
# <br><br>
#
#
# ## **Analysis**
# ---

# %% [markdown]
# ### **Q. How much money has been borrowed through Kiva's lending platform?**

# %%
kiva_loans.head()
# Out:
#                  id  funded_amount  ...  lender_count repayment_interval
# date                                ...
# 2016-01-01  1002924            500  ...             1            monthly
# 2016-01-01  1002908            500  ...             1          irregular
# 2016-01-01  1002897            500  ...            17            monthly
# 2016-01-01  1002916            500  ...            16          irregular
# 2016-01-01  1002891            575  ...            21          irregular
#
# [5 rows x 13 columns]

# %%
total_loans = kiva_loans['funded_amount'].sum() / 1000000

print('There has been $' + str(round(total_loans, 1)) + ' million in loans funded by Kiva')
# Out:
# There has been $232.5 million in loans funded by Kiva

# %% [markdown]
# <br><br>
#
# ### **Q. How has the amount of funding changed over time?**

# %%
loans_by_day = kiva_loans.groupby('date')['funded_amount'].sum()

# plt.plot(loans_by_day)
# plt.show()

loans_by_month = loans_by_day.resample('M').sum()

loans_by_month = loans_by_month[loans_by_month.index < '2017-06-01']

plt.plot(loans_by_month)
plt.title('Total Kiva Loans funded: Jan 2016 - May 2017')
plt.xlabel('Date')
plt.ylabel('Amount funded in millions ($)')
plt.show()

# %% [markdown]
# <br><br>
#
# ### **Q. How much funding has been provided by sector?**

# %%
kiva_loans.head()
# Out:
#                  id  funded_amount  ...  lender_count repayment_interval
# date                                ...
# 2016-01-01  1002924            500  ...             1            monthly
# 2016-01-01  1002908            500  ...             1          irregular
# 2016-01-01  1002897            500  ...            17            monthly
# 2016-01-01  1002916            500  ...            16          irregular
# 2016-01-01  1002891            575  ...            21          irregular
#
# [5 rows x 13 columns]

# %%
loans_by_sector = kiva_loans.groupby('sector')['funded_amount'].sum()
loans_by_sector.sort_values(ascending=False, inplace=True)

# %%
loans_by_sector.plot.bar()
plt.title('Funded Kiva loans by sector')
plt.ylabel('Amount funded in millions ($)')
plt.show()

# %% [markdown]
# <br><br>
#
# ### **Q. How does funding vary by world region?**

# %%
kiva_loans.head()
# Out:
#                  id  funded_amount  ...  lender_count repayment_interval
# date                                ...
# 2016-01-01  1002924            500  ...             1            monthly
# 2016-01-01  1002908            500  ...             1          irregular
# 2016-01-01  1002897            500  ...            17            monthly
# 2016-01-01  1002916            500  ...            16          irregular
# 2016-01-01  1002891            575  ...            21          irregular
#
# [5 rows x 13 columns]

# %%
locations.head()
# Out:
#               LocationName  ISO  ...        lat        lon
# 0  Badakhshan, Afghanistan  AFG  ...  36.734772  70.811995
# 1     Badghis, Afghanistan  AFG  ...  35.167134  63.769538
# 2     Baghlan, Afghanistan  AFG  ...  35.804295  69.287754
# 3       Balkh, Afghanistan  AFG  ...  36.755060  66.897537
# 4      Bamyan, Afghanistan  AFG  ...  34.810007  67.821210
#
# [5 rows x 9 columns]

# %%
loans_and_locations = kiva_loans.merge(locations, how='left', on='country')

# %%
loans_by_wregion = loans_and_locations.groupby('world_region')['funded_amount'].sum()

# %%
colors = [(0.953125720876586, 0.9822068435217225, 0.9426989619377163, 1.0),
 (0.12110726643598617, 0.5312572087658592, 0.2590542099192618, 1.0),
 (0.9686274509803922, 0.9882352941176471, 0.9607843137254902, 1.0),
 (0.0, 0.26666666666666666, 0.10588235294117647, 1.0),
 (0.9664129181084199, 0.9873740868896579, 0.9582006920415225, 1.0),
 (0.4798154555940023, 0.7802537485582468, 0.48322952710495964, 1.0)]

# %%
squarify.plot(sizes=loans_by_wregion
              , label=loans_by_wregion.index
              , color=colors
              , alpha=0.5
              , edgecolor='black'
              , pad=True)
plt.title('Kiva funding by region')
plt.axis('off')

plt.show()

# %% [markdown]
# <br><br>
#
# ### **Q. What are the most popular sectors in each region?**

# %%
sector_region_pivot = loans_and_locations.pivot_table(index='sector'
                               , columns='world_region'
                               , values='funded_amount'
                               , aggfunc='sum')

# %%
sector_region_pivot.style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_833315f0_26ee_11eb_ad31_0242ac1c0002row0_col0,#T_833315f0_26ee_11eb_ad31_0242ac1c0002row0_col1,#T_833315f0_26ee_11eb_ad31_0242ac1c0002row0_col2,#T_833315f0_26ee_11eb_ad31_0242ac1c0002row0_col3,#T_833315f0_26ee_11eb_ad31_0242ac1c0002row0_col5,#T_833315f0_26ee_11eb_ad31_0242ac1c0002row12_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_833315f0_26ee_11eb_ad31_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >world_region</th>        <th class="col_heading level0 col0" >Arab States</th>        <th class="col_heading level0 col1" >East Asia and the Pacific</th>        <th class="col_heading level0 col2" >Europe and Central Asia</th>        <th class="col_heading level0 col3" >Latin America and Caribbean</th>        <th class="col_heading level0 col4" >South Asia</th>        <th class="col_heading level0 col5" >Sub-Saharan Africa</th>    </tr>    <tr>        <th class="index_name level0" >sector</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
000000</td>
#             </tr>
#             <tr>
#                         <th id="T_833315f0_26ee_11eb_ad31_0242ac1c0002level0_row4" class="row_heading level0 row4" >Education</th>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col0" class="data row4 col0" >2400075.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col1" class="data row4 col1" >11658050.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col2" class="data row4 col2" >4185375.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col3" class="data row4 col3" >24057700.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col4" class="data row4 col4" >6787350.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row4_col5" class="data row4 col5" >21176625.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_833315f0_26ee_11eb_ad31_0242ac1c0002level0_row5" class="row_heading level0 row5" >Entertainment</th>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col0" class="data row5 col0" >18900.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col1" class="data row5 col1" >534650.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col2" class="data row5 col2" >11000.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col3" class="data row5 col3" >830425.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col4" class="data row5 col4" >39900.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row5_col5" class="data row5 col5" >309775.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_833315f0_26ee_11eb_ad31_0242ac1c0002level0_row6" class="row_heading level0 row6" >Food</th>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col0" class="data row6 col0" >5181575.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col1" class="data row6 col1" >129857925.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col2" class="data row6 col2" >2463375.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col3" class="data row6 col3" >178052350.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col4" class="data row6 col4" >3892750.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row6_col5" class="data row6 col5" >113519775.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_833315f0_26ee_11eb_ad31_0242ac1c0002level0_row7" class="row_heading level0 row7" >Health</th>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row7_col0" class="data row7 col0" >34050.000000</td>
#                         <td id="T_833315f0_26ee_11eb_ad31_0242ac1c0002row7_col1" class="data row7 col1" >2538
